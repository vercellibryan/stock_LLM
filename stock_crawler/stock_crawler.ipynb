# %% [markdown]
# # Stock Crawler

# %%
# %pip install yfinance
import yfinance as yf

# %% [markdown]
# ## Get historical stock data

# %%
ticker = yf.Ticker("NVDA")

# %%
df = ticker.history(start="2024-01-01", end="2024-06-01")
print(df.head())
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2024-01-02 00:00:00-05:00  49.156626  49.207534  47.510553  48.082535
# 2024-01-03 00:00:00-05:00  47.400742  48.098499  47.236034  47.484592
# 2024-01-04 00:00:00-05:00  47.682253  48.413954  47.423713  47.912846
# 2024-01-05 00:00:00-05:00  48.376012  49.459086  48.220287  49.009884
# 2024-01-08 00:00:00-05:00  49.424156  52.182254  49.391213  52.160290
#
#                               Volume  Dividends  Stock Splits
# Date
# 2024-01-02 00:00:00-05:00  411254000        0.0           0.0
# 2024-01-03 00:00:00-05:00  320896000        0.0           0.0
# 2024-01-04 00:00:00-05:00  306535000        0.0           0.0
# 2024-01-05 00:00:00-05:00  415039000        0.0           0.0
# 2024-01-08 00:00:00-05:00  642510000        0.0           0.0

# %% [markdown]
# ## Company info

# %%
ticker.info
# Out:
# {'address1': '2788 San Tomas Expressway',
#  'city': 'Santa Clara',
#  'state': 'CA',
#  'zip': '95051',
#  'country': 'United States',
#  'phone': '408 486 2000',
#  'website': 'https://www.nvidia.com',
#  'industry': 'Semiconductors',
#  'industryKey': 'semiconductors',
#  'industryDisp': 'Semiconductors',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
# ...
